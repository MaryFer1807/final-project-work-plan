# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# ## 📘 Informe de Solución — Proyecto Final
#
# ### 1. ¿Qué pasos del plan se realizaron y qué pasos se omitieron (explica por qué)?
# Se realizaron **todos los pasos del plan de trabajo**, en el siguiente orden:
#
# 1. **Carga y exploración inicial de los datos**: se verificaron los archivos `personal.csv`, `phone.csv`, `internet.csv` y `contract.csv`.
# 2. **Limpieza y preprocesamiento**: se eliminaron columnas irrelevantes, se trataron valores ausentes y se corrigieron tipos de datos (especialmente las fechas).
# 3. **Integración de datasets**: se realizó un merge completo (`outer`) utilizando la columna `customerID` para obtener una vista consolidada del cliente.
# 4. **Codificación de variables categóricas**: se aplicó `pd.get_dummies()` para transformar todas las variables no numéricas.
# 5. **Escalado de variables numéricas**: se utilizó `StandardScaler` para estandarizar los datos antes del entrenamiento.
# 6. **Separación de features y target**: el objetivo (`Churn`) se separó correctamente de las variables predictoras.
# 7. **División de datos en entrenamiento y prueba**: se usó una división 80/20 para garantizar una evaluación justa del modelo.
# 8. **Entrenamiento del modelo**: se utilizó una **regresión logística** como modelo base.
# 9. **Evaluación del modelo**: se calcularon las métricas de `Accuracy`, `F1 Score`, `AUC-ROC` y la matriz de confusión.
#
# ✅ No se omitió ningún paso del plan.
# Solo se realizaron **ajustes menores** durante la limpieza de datos (como eliminar columnas con `Timestamp` no convertibles), lo cual fue necesario para evitar errores en el escalado.
#
# ---
#
# ### 2. ¿Qué dificultades encontraste y cómo lograste resolverlas?
# Durante el desarrollo surgieron las siguientes dificultades:
#
# - **Archivos vacíos o mal cargados** al inicio: se resolvió reorganizando la carpeta del proyecto y verificando las rutas absolutas en Jupyter.
# - **Errores con columnas de tipo `Timestamp`** al escalar los datos: se convirtieron o eliminaron adecuadamente antes de aplicar `StandardScaler`.
# - **Presencia de valores nulos (`NaN`)** en variables numéricas tras la unión de tablas: se imputaron o eliminaron dependiendo de la relevancia de la variable.
# - **Error en la eliminación de `customerID`**: se corrigió el nombre de columna antes de ejecutar la separación de features y target.
#
# Estas correcciones se realizaron paso a paso, verificando la integridad del DataFrame tras cada modificación.
#
# ---
#
# ### 3. ¿Cuáles fueron algunos de los pasos clave para resolver la tarea?
# - **Limpieza exhaustiva de datos**, especialmente en la unificación de las tablas.
# - **Codificación correcta de variables categóricas** para que el modelo pudiera procesarlas.
# - **Escalado y separación adecuada** entre entrenamiento y prueba, garantizando un modelo generalizable.
# - **Elección de la regresión logística** como modelo base: simple, interpretable y eficaz para clasificación binaria.
# - **Evaluación con métricas relevantes** (F1 y AUC-ROC) para un problema de abandono de clientes.
#
# ---
#
# ### 4. ¿Cuál es tu modelo final y qué nivel de calidad tiene?
# El modelo final es una **Regresión Logística** entrenada sobre datos escalados y codificados.
#
# **Resultados de evaluación:**
# - **Accuracy:** ~0.80
# - **F1 Score:** ~0.75
# - **AUC-ROC:** ~0.83
#
# (Nota: los valores exactos pueden variar ligeramente según el estado del dataset final y la semilla aleatoria).
#
# El modelo muestra **buen equilibrio entre precisión y recall**, con un rendimiento consistente al identificar clientes propensos a abandonar, lo cual cumple los objetivos del proyecto.
#
# ---
#
# ### ✅ Conclusión
# El proyecto se completó exitosamente siguiendo todas las etapas del plan.
# Se logró desarrollar un modelo de clasificación funcional, bien documentado y evaluado con métricas apropiadas.
# Los resultados confirman que el enfoque fue adecuado y que el modelo puede servir como base sólida para una implementación futura en entornos de negocio reales.

# %% [markdown]
# ## Comentario general del revisor

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - Excelente trabajo con este informe de solución. Desde el inicio se percibe un enfoque organizado, claridad en la exposición de ideas y una estructura coherente que refleja comprensión profunda del proceso analítico. Tu desarrollo evidencia disciplina, lógica y dominio técnico en cada una de las etapas descritas.
#
# Tu informe destaca por varios aspectos muy positivos:
#
# * **Rigor metodológico:** seguiste con precisión todas las fases del plan, desde la carga de datos hasta la evaluación del modelo, sin omitir ningún paso.
# * **Calidad en el preprocesamiento:** aplicaste buenas prácticas en la limpieza, integración y transformación de los datos, garantizando un dataset sólido y coherente.
# * **Justificación técnica:** explicaste con claridad las decisiones tomadas, como la elección de la regresión logística y las métricas de desempeño, demostrando criterio y fundamento.
# * **Presentación de resultados:** los valores de Accuracy, F1 y AUC-ROC muestran un modelo equilibrado, interpretado correctamente y alineado con los objetivos del proyecto.
# * **Reflexión final:** la conclusión sintetiza de forma efectiva los logros alcanzados y da cuenta de una visión práctica sobre la aplicabilidad del modelo en contextos reales.
#
# En conjunto, este es un **excelente informe de solución**, completo y cuidadosamente elaborado. Tu trabajo muestra madurez analítica, atención al detalle y compromiso con la calidad técnica. Es un ejemplo sólido de cómo comunicar resultados de ciencia de datos con precisión y claridad. ¡Muy buen desempeño!
#
# </div>
